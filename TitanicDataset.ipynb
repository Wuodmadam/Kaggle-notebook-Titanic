# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import warnings

# %%
# Suppress unncessary warnings in the output
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", message=".*tight_layout.*", category=UserWarning)

warnings.filterwarnings(
    "ignore",
    message=".*The figure layout has changed to tight.*",
    category=UserWarning
)

# %% [markdown]
# 1.**Profile the list of features and analyze their data types, missing values, duplicates, errors, and plots you can explore per feature. Here are some essential pandas functions used for initial exploration:**

# %%
#set A seaborn style for visualisation
sns.set_style("darkgrid")

# %%
df=pd.read_csv('/kaggle/input/titanic-dataset/Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
duplicate_rows = df.duplicated().sum()
print("Duplicate_Rows:")
print(duplicate_rows)
# Out:
# Duplicate_Rows:
# 0

# %%
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 2. Univariate Data Analysis

# %%
#Age Distribution of the passengers
# Numerical: Age (handle missing with median for visualization)
df['Age_imputed'] = df['Age'].fillna(df['Age'].median())#this code imputes missing age with median
plt.figure(figsize=(8, 5))
sns.histplot(df['Age_imputed'], bins=30, kde=True, color='black')
plt.title('Age Distribution (Imputed)')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
# Fare ditribution
plt.figure(figsize=(8, 5))
sns.histplot((df['Fare']), bins=30, kde=True, color='salmon')
plt.title('Fare Distribution')
plt.xlabel('Fare Range')
plt.ylabel('Density')
plt.show()

# %%
# Embarked
plt.figure(figsize=(6, 4))
sns.countplot(x='Embarked', data=df, palette='Set1')
plt.title('Embarked Distribution')
plt.xlabel('Embarked (C = Cherbourg, Q = Queenstown, S = Southampton)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
#fare against pclas(passenger class)
plt.figure(figsize=(8, 5))
sns.boxplot(x='Pclass', y='Fare', data=df, palette='Set2')
plt.title('Fare by Passenger Class')
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.ylim(0, 200)  # Cap for visibility
plt.show()

# %%
# Embarked vs. Survived
plt.figure(figsize=(6, 4))
sns.countplot(x='Embarked', hue='Survived', data=df, palette='Set1')
plt.title('Survival by Embarked')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.show()

# %%
# Age vs. Survived
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Age_imputed', hue='Survived', bins=30, kde=True, palette='Set1', stat='density')
plt.title('Age Distribution by Survival')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
#Embarked vs Survived
plt.figure(figsize=(6, 4))
sns.countplot(x='Embarked', hue='Survived', data=df, palette='Set1')
plt.title('Survival by Embarked')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Multivariate Analysis
#
# 1. How do Pclass, Age, and Fare jointly affect survival?
# 2. Are survival rates different for embarked locations when considering Pclass?

# %%
# Pclass, Age, Fare vs. Survived (pairplot for numerical features)
sns.pairplot(df[['Age_imputed', 'Fare', 'Pclass', 'Survived']], hue='Survived', palette='Set1')
plt.suptitle('Pairplot: Pclass, Age, Fare vs. Survived', y=1.02)
plt.show()

# %%
# Embarked, Pclass, Survived (catplot)
sns.catplot(x='Pclass', hue='Survived', col='Embarked', data=df, kind='count', palette='Set1')
plt.suptitle('Survival by Pclass and Embarked', y=1.05)
plt.show()

# %% [markdown]
# Outlier Detection
# 1. Removing outliers in Fare may help for predictive models, but could hide important insights for understanding passenger wealth.

# %%
# --- Outlier Detection ---
# fare: Boxplot to detect outliers
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Fare'], color='skyblue')
plt.title('Fare Outlier Detection')
plt.xlabel('Fare')
plt.show()

# %% [markdown]
# I chose to leave the fare outliers as both extremes were present at large
